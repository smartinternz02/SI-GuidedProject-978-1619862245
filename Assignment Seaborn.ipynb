# %%
import seaborn as s
s
# Out:
# <module 'seaborn' from 'C:\\Users\\Varun\\Anaconda3\\lib\\site-packages\\seaborn\\__init__.py'>

# %%
import numpy as np
np
# Out:
# <module 'numpy' from 'C:\\Users\\Varun\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>

# %%
iris = s.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
s.scatterplot( x="petal_length" , y="petal_width" , data = iris)

# %%
s.lineplot( x = "sepal_length" , y = "sepal_width" , data = iris)

# %%
s.distplot(iris["petal_length"])

# %%
s.barplot( x = "species" , y = "petal_width" , data = iris)

# %%
s.boxplot( x = "species" , y = "petal_width" , data = iris)

# %%
s.catplot( x = "species" , y = "sepal_width" , data = iris)

# %%
s.pairplot(iris)

# %%
s.heatmap(iris.corr())
